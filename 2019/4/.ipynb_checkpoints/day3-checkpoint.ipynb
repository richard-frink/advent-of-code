# %%
import sys
import os
import itertools
# !conda install --yes --prefix {sys.prefix} -c ulmo urllib3

# %%
def get_input_file(file):
    lines = []
    with open(file) as f:
       lines = f.readlines()
    return lines[0], lines[1]

def get_input_from_lines(line1, line2):
    wire1 = [[path[0], int(path[1:])] for path in line1.split(',')]
    wire2 = [[path[0], int(path[1:])] for path in line2.split(',')]
    return wire1, wire2

# %%
def traverse_path(x_apply, y_apply, x_start, y_start, distance):
    traversals = []
    for i in range(1, distance + 1, 1):
        x_start += x_apply
        y_start += y_apply
        traversals.append([x_start, y_start])
    return x_start, y_start, traversals
    
def traverse_action(action, x, y):
    direction = action[0]
    distance = action[1]
    if direction == "U":
        return traverse_path(0, 1, x, y, distance)
    if direction == "D":
        return traverse_path(0, -1, x, y, distance)
    if direction == "L":
        return traverse_path(-1, 0, x, y, distance)
    if direction == "R":
        return traverse_path(1, 0, x, y, distance)

def traverse_wire(wire):
    x = 0
    y = 0
    grouped_coordinates = []
    for action in wire:
        new_x, new_y, traversals = traverse_action(action, x, y)
        x = new_x
        y = new_y
        grouped_coordinates.append(traversals)
    coordinates = [str(coordinate[0]) + ',' + str(coordinate[1]) for group in grouped_coordinates for coordinate in group]
    return coordinates
    
def solve1(wire1, wire2):
    intersections = []
    wire1_traversals = []
    wire2_traversals = []

    wire1_traversals = set(traverse_wire(wire1))
    wire2_traversals = traverse_wire(wire2)
    
    intersections = filter(lambda coordinate: coordinate in wire1_traversals, wire2_traversals)
    intersections = map(lambda i: i.split(','), intersections)
    intersections = map(lambda i: [int(i[0]), int(i[1])], intersections)
    distances = [(abs(intersection[0]) + abs(intersection[1])) for intersection in intersections]
    print(min(distances))

# %%
def solve2(wire1, wire2):
    print(wire1, wire2)

# %%
def main():
    line1, line2 = get_input_file('input.txt')
    wire1, wire2 = get_input_from_lines(line1, line2)
    
    tests = [['R75,D30,R83,U83,L12,D49,R71,U7,L72','U62,R66,U55,R34,D71,R55,D58,R83'],
             ['R98,U47,R26,D63,R33,U87,L62,D20,R33,U53,R51','U98,R91,D20,R16,D67,R40,U7,R15,U6,R7']]
    
    for test in tests:
        test_wire1, test_wire2 = get_input_from_lines(test[0], test[1])
        solve1(test_wire1, test_wire2)
    
    solve1(wire1, wire2)
    solve2(wire1, wire2)

# %%
main()
# Out:
# 159
# 135
# 403
# [['R', 992], ['U', 221], ['L', 822], ['U', 805], ['R', 667], ['D', 397], ['L', 969], ['U', 433], ['R', 918], ['D', 517], ['L', 494], ['U', 909], ['L', 224], ['D', 738], ['R', 247], ['D', 312], ['L', 803], ['D', 656], ['L', 571], ['D', 968], ['L', 392], ['D', 332], ['L', 581], ['U', 487], ['R', 522], ['D', 780], ['L', 74], ['D', 561], ['L', 246], ['U', 380], ['L', 125], ['U', 11], ['R', 735], ['D', 761], ['R', 482], ['D', 208], ['R', 985], ['D', 991], ['L', 352], ['U', 140], ['L', 586], ['D', 492], ['L', 777], ['U', 96], ['R', 682], ['D', 969], ['R', 775], ['U', 279], ['R', 671], ['D', 423], ['R', 838], ['U', 907], ['L', 486], ['D', 702], ['L', 432], ['D', 625], ['R', 463], ['U', 559], ['R', 12], ['D', 531], ['R', 510], ['D', 347], ['R', 147], ['U', 949], ['R', 175], ['U', 160], ['L', 975], ['D', 627], ['L', 537], ['D', 343], ['L', 406], ['D', 237], ['R', 953], ['U', 725], ['L', 996], ['D', 740], ['L', 703], ['D', 996], ['R', 157], ['U', 356], ['R', 247], ['D', 541], ['L', 592], ['D', 345], ['R', 580], ['U', 656], ['R', 50], ['D', 423], ['L', 158], ['U', 502], ['L', 86], ['U', 729], ['L', 720], ['D', 464], ['R', 901], ['D', 739], ['L', 20], ['U', 21], ['R', 497], ['D', 14], ['L', 580], ['U', 610], ['L', 114], ['D', 858], ['R', 853], ['U', 550], ['L', 354], ['D', 433], ['L', 507], ['U', 144], ['R', 9], ['U', 422], ['R', 674], ['U', 604], ['R', 107], ['D', 999], ['L', 420], ['U', 675], ['R', 538], ['D', 491], ['R', 84], ['D', 158], ['R', 303], ['D', 450], ['L', 616], ['U', 938], ['L', 162], ['U', 102], ['L', 160], ['U', 275], ['L', 281], ['D', 164], ['L', 254], ['U', 103], ['R', 60], ['D', 707], ['R', 655], ['U', 128], ['L', 907], ['U', 225], ['L', 292], ['U', 919], ['R', 517], ['D', 276], ['R', 308], ['D', 113], ['L', 455], ['U', 584], ['R', 899], ['U', 321], ['L', 417], ['U', 449], ['L', 780], ['U', 387], ['L', 579], ['U', 224], ['L', 192], ['D', 325], ['L', 626], ['U', 145], ['R', 178], ['D', 162], ['L', 18], ['D', 469], ['R', 169], ['U', 694], ['R', 162], ['D', 806], ['L', 10], ['U', 979], ['L', 944], ['D', 304], ['R', 719], ['D', 253], ['L', 343], ['D', 711], ['R', 429], ['D', 933], ['R', 445], ['D', 772], ['R', 230], ['D', 407], ['R', 335], ['U', 883], ['L', 900], ['D', 377], ['R', 413], ['D', 44], ['R', 805], ['D', 378], ['R', 421], ['D', 860], ['L', 597], ['U', 63], ['L', 583], ['D', 561], ['R', 235], ['D', 502], ['L', 37], ['U', 29], ['L', 381], ['U', 803], ['R', 588], ['D', 972], ['R', 678], ['D', 223], ['L', 440], ['U', 835], ['R', 88], ['D', 16], ['R', 529], ['D', 867], ['R', 742], ['U', 25], ['R', 353], ['D', 952], ['R', 31], ['D', 202], ['R', 737], ['D', 744], ['R', 765], ['U', 154], ['L', 969], ['U', 851], ['L', 22], ['U', 165], ['L', 12], ['D', 457], ['R', 635], ['U', 829], ['L', 996], ['D', 871], ['L', 397], ['U', 995], ['R', 215], ['D', 505], ['R', 93], ['U', 12], ['R', 183], ['D', 920], ['L', 442], ['D', 393], ['L', 919], ['D', 803], ['R', 22], ['D', 806], ['R', 776], ['U', 558], ['R', 263], ['D', 222], ['R', 111], ['D', 530], ['L', 908], ['D', 640], ['R', 351], ['D', 172], ['R', 315], ['U', 731], ['R', 25], ['U', 718], ['L', 172], ['D', 145], ['L', 606], ['U', 803], ['R', 837], ['U', 310], ['L', 607], ['D', 523], ['R', 271], ['U', 927], ['R', 3], ['U', 518], ['R', 754], ['D', 322], ['L', 924], ['D', 256], ['L', 997], ['U', 153], ['L', 904], ['D', 745], ['L', 475], ['U', 346], ['L', 979], ['D', 658], ['R', 208], ['U', 924], ['L', 484], ['U', 961], ['R', 94], ['D', 283], ['L', 79], ['U', 927], ['R', 122], ['D', 513], ['L', 806], ['D', 480], ['L', 971], ['U', 340], ['R', 328], ['D', 427], ['L', 494]] [['L', 998], ['U', 308], ['R', 889], ['D', 471], ['R', 719], ['U', 326], ['L', 6], ['U', 802], ['L', 608], ['U', 149], ['R', 454], ['U', 6], ['R', 837], ['U', 255], ['L', 720], ['D', 60], ['L', 426], ['D', 525], ['L', 190], ['U', 995], ['R', 676], ['U', 172], ['R', 910], ['U', 645], ['R', 249], ['D', 725], ['R', 355], ['U', 668], ['L', 988], ['U', 253], ['L', 820], ['D', 266], ['R', 836], ['D', 750], ['R', 998], ['U' ...
